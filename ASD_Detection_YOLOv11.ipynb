# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.166 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 41.7/235.7 GB disk)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: creat yaml file

# %%writefile data.yaml

    train: /content/drive/MyDrive/Colab Notebooks/Autism.v3i.yolov11/train/images
    val: /content/drive/MyDrive/Colab Notebooks/Autism.v3i.yolov11/valid/images
    test: /content/drive/MyDrive/Colab Notebooks/Autism.v3i.yolov11/test/images
    nc: 16
    names : ['Weird_Expression', 'Twirling', 'Toe_Walking', 'SIB_Biting', 'Shaking_Legs', 'Jumping', 'Holding_Item', 'Head_Banging', 'Hand_Flapping', 'Hand_Clapping', 'Finger_Biting', 'Finger_Flicking', 'Covering_Ears', 'Avoid_Eye_Contact', 'Aggressive_behaviour', 'Tpot_Stimming' ]
# Out:
# Writing data.yaml

# %%
from ultralytics import YOLO

# Build a YOLOv6n model from scratch
model = YOLO("yolo11l.pt")

# Display model information (optional)
model.info()

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data= "data.yaml", epochs=200, imgsz=640)
# Out:
# ...
# 100%|██████████| 49.0M/49.0M [00:00<00:00, 115MB/s]
# YOLO11l summary: 357 layers, 25,372,160 parameters, 0 gradients, 87.6 GFLOPs
# Ultralytics 8.3.166 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
# !cp -r runs/detect/train /content/drive/MyDrive/yolov11_training_results/
